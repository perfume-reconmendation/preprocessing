# %% [markdown]
# ## Profile

# %%
import pandas as pd

df = pd.read_csv('../output/preprocessed_2.csv')
df
# Out:
#    Unnamed: 0  gender                    name  \
# 0           0  female  Alien Mugler for women
# 1           1  female  Alien Mugler for women
# 2           2  female  Alien Mugler for women
# 3           3  female  Alien Mugler for women
# 4           4  female  Alien Mugler for women
# 5           5  female  Alien Mugler for women
# 6           4  female  Alien Mugler for women
# 7           5  female  Alien Mugler for women
# 8           6  female  Alien Mugler for women
# 9           7  female  Alien Mugler for women
#
#                               accords  \
# 0  ['white floral', 'amber', 'woody']
# 1  ['white floral', 'amber', 'woody']
# 2  ['white floral', 'amber', 'woody']
# 3  ['white floral', 'amber', 'woody']
# 4  ['white floral', 'amber', 'woody']
# 5  ['white floral', 'amber', 'woody']
# 6  ['white floral', 'amber', 'woody']
# 7  ['white floral', 'amber', 'woody']
# 8  ['white floral', 'amber', 'woody']
# 9  ['white floral', 'amber', 'woody']
#
# ...

# %%
from random import randrange

i = randrange(1, len(df['review']))
rec = df[i:i+1]

print(f'idx: {rec.index.start}')
print(f'name: {rec["name"].values[0]}')
print(f'accords: {rec["accords"].values[0]}')
print(f'review: {rec["review"].values[0]}')
print(f'tokenized: {rec["tokenized"].values[0]}')
print(f'only_english: {rec["only_english"].values[0]}')
print(f'longer_than_2: {rec["longer_than_2_A"].values[0]}')
print(f'stopwords_removed: {rec["stopwords_removed"].values[0]}')
print(f'lemmatizated: {rec["lemmatizated"].values[0]}')
# Out:
# idx: 8
# name: Alien Mugler for women
# accords: ['white floral', 'amber', 'woody']
# review: For the last six months I've been hearing good and bad reviews from this one. And I was thinking should I blind buy it or not. A lot of people say "don't blind buy it!"
# Today I went to smell this beauty for the first time😍 and for me it smelled very fresh and simple. A very clean smell, just like some people said "soapy vibe". Maybe even detergent, hahaha I also like that smell 🙈
# I thought this would be a heavy headache smell, but not. I sprayed it today on my hair and wrists, and after an hour I saw my father who gave me a compliment!
# On my skin it lasted like 6h (with a very good sillage!), and I have a feeling that on my hair it would smell till tomorrow, because it's still in it.
# I don't know how someone could not like this perfume 😂 I think it just smells like fresh laundry in a good way ♥️ I would definitely buy this one day!
# ...

# %%
df
# Out:
#    Unnamed: 0  gender                    name  \
# 0           0  female  Alien Mugler for women
# 1           1  female  Alien Mugler for women
# 2           2  female  Alien Mugler for women
# 3           3  female  Alien Mugler for women
# 4           4  female  Alien Mugler for women
# 5           5  female  Alien Mugler for women
# 6           4  female  Alien Mugler for women
# 7           5  female  Alien Mugler for women
# 8           6  female  Alien Mugler for women
# 9           7  female  Alien Mugler for women
#
#                               accords  \
# 0  ['white floral', 'amber', 'woody']
# 1  ['white floral', 'amber', 'woody']
# 2  ['white floral', 'amber', 'woody']
# 3  ['white floral', 'amber', 'woody']
# 4  ['white floral', 'amber', 'woody']
# 5  ['white floral', 'amber', 'woody']
# 6  ['white floral', 'amber', 'woody']
# 7  ['white floral', 'amber', 'woody']
# 8  ['white floral', 'amber', 'woody']
# 9  ['white floral', 'amber', 'woody']
#
# ...

# %%
df_2 = pd.read_csv('../dataset/top_90_by_gender.csv')
df_2[4700:7000]
# Out:
#       gender                                      name  \
# 4700  female           Black Orchid Tom Ford for women
# 4701  female           Black Orchid Tom Ford for women
# 4702  female           Black Orchid Tom Ford for women
# 4703  female           Black Orchid Tom Ford for women
# 4704  female           Black Orchid Tom Ford for women
# ...      ...                                       ...
# 6995  female  Hypnotic Poison Christian Dior for women
# 6996  female  Hypnotic Poison Christian Dior for women
# 6997  female  Hypnotic Poison Christian Dior for women
# 6998  female  Hypnotic Poison Christian Dior for women
# 6999  female  Hypnotic Poison Christian Dior for women
#
#                                                 accords  \
# 4700  ['warm spicy', 'earthy', 'woody', 'sweet', 'am...
# 4701  ['warm spicy', 'earthy', 'woody', 'sweet', 'am...
# 4702  ['warm spicy', 'earthy', 'woody', 'sweet', 'am...
# 4703  ['warm spicy', 'earthy', 'woody', 'sweet', 'am...
# ...
